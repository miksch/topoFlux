# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
origin = [0,0]
test_vector = [4, 3]
thetas = [-83, 90, 12, 30]

# %%
fig, ax = plt.subplots(**{'figsize':(5,5)})

scale = 20
ax.quiver(*origin, *test_vector, label='Original', scale=scale)

for i, t in enumerate(thetas):
    rotate_vector = rotate_2d(*test_vector, t)
    print(rotate_vector)
    ax.quiver(*origin, *rotate_vector, label=r"$\theta = $"+f"{t}"+r"$\degree$", 
              scale=scale, color=f'C{i}')

ax.legend()
ax.grid()
# Out:
# (3.4651158285445556, -3.6045765763498454)
# (-2.9999999999999996, 4.0)
# (3.288855330481945, 3.7660895654724547)
# (1.964101615137755, 4.598076211353316)
