# %%
import pandas as pd
import numpy as np
import xarray as xr
import os

from utils import unit_convert
from utils import coord_rotate

# %%
ws1, wd1 = unit_convert.uv_to_wswd(-5,1)
u1, v1 = unit_convert.wswd_to_uv(ws1, wd1)

# %%
print(ws1, wd1)
print(u1, v1)
# Out:
# 5.0990195135927845 101.30993247402021
# -4.999999999999999 1.0000000000000002

# %%
# Coordinate rotation for the shadow corrections

# DR rotation

# asdf

# %%
cases_fp = 'C:/Users/moo90/Box/data/cases99/cases_tower_hr_19991006_00.nc'

test_cases = xr.open_dataset(cases_fp)

print(test_cases)
# Out:
# <xarray.Dataset>
# Dimensions:       (station: 6, time: 834001)
# Coordinates:
#   * station       (station) |S2 b's1' b's2' b's3' b's4' b's5' b's6'
#   * time          (time) datetime64[ns] 1999-10-06T00:25:00 ... 1999-10-06T12:00:00
# Data variables:
#     base_time     datetime64[ns] ...
#     u_1_5m        (time) float32 ...
#     v_1_5m        (time) float32 ...
#     w_1_5m        (time) float32 ...
#     tc_1_5m       (time) float32 ...
#     diag_1_5m     (time) float32 ...
#     pp_1_5m       (time) float32 ...
#     u_5m          (time) float32 ...
#     v_5m          (time) float32 ...
#     w_5m          (time) float32 ...
#     tc_5m         (time) float32 ...
#     diag_5m       (time) float32 ...
#     kh2o_5m       (time) float32 ...
#     co2mr_5m      (time) float32 ...
#     u_10m         (time) float32 ...
#     v_10m         (time) float32 ...
#     w_10m         (time) float32 ...
#     tc_10m        (time) float32 ...
#     usamples_10m  (time) float32 ...
# ...

# %%
chats_fp = 'C:/Users/moo90/Box/data/chats/5min/isff_20070317.nc'

test_chats = xr.open_dataset(chats_fp)

print(test_chats)
# Out:
# <xarray.Dataset>
# Dimensions:                 (time: 288)
# Coordinates:
#   * time                    (time) datetime64[ns] 2007-03-17T00:02:30 ... 2007-03-17T23:57:30
# Data variables:
#     base_time               datetime64[ns] ...
#     counts_1t_10_6m         (time) float64 ...
#     u_1t_10_6m_ha           (time) float32 ...
#     v_1t_10_6m_ha           (time) float32 ...
#     w_1t_10_6m_ha           (time) float32 ...
#     tc_1t_10_6m_ha          (time) float32 ...
#     u_u__1t_10_6m_ha        (time) float32 ...
#     u_v__1t_10_6m_ha        (time) float32 ...
#     u_w__1t_10_6m_ha        (time) float32 ...
#     u_tc__1t_10_6m_ha       (time) float32 ...
#     v_v__1t_10_6m_ha        (time) float32 ...
#     v_w__1t_10_6m_ha        (time) float32 ...
#     v_tc__1t_10_6m_ha       (time) float32 ...
#     w_w__1t_10_6m_ha        (time) float32 ...
#     w_tc__1t_10_6m_ha       (time) float32 ...
#     tc_tc__1t_10_6m_ha      (time) float32 ...
# ...
